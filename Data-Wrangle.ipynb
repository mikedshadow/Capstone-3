# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from scipy.stats import shapiro
from statsmodels.graphics.gofplots import qqplot
from datetime import date, timedelta
# %matplotlib inline

# %%
# read the VIX prices
## https://www.cboe.com/tradable_products/vix/vix_historical_data/
df = pd.read_csv(r"C:\Users\micha\Documents\Springboard\Capstone-3\Data\VIX_History.csv")
# read the kaggle dataset ------- put link and citations
## https://www.kaggle.com/datasets/miguelaenlle/massive-stock-news-analysis-db-for-nlpbacktests?select=raw_partner_headlines.csv
df_hdl = pd.read_csv(r"C:\Users\micha\Documents\Springboard\Capstone-3\Data\analyst_ratings_processed.csv")

# %%
df_hdl.isnull().sum()
# Out:
# Unnamed: 0    1289
# title            0
# date          1289
# stock         2578
# dtype: int64

# %%
## set both date columns to datetime
df_hdl['date'] = pd.to_datetime(df_hdl['date'],utc=True, errors='coerce')
df['DATE'] = pd.to_datetime(df['DATE'], utc=True)

# %%
df_hdl.isnull().sum()
# Out:
# Unnamed: 0    1289
# title            0
# date          2578
# stock         2578
# dtype: int64

# %%
df_hdl[df_hdl['date'].isnull()].sample(20)
# Out:
#          Unnamed: 0                                              title date  \
# 1388370         NaN                          2011-07-21 11:25:00-04:00  NaT
# 351042          NaN                          2011-03-22 06:30:00-04:00  NaT
# 731960          NaN                          2011-06-16 09:33:00-04:00  NaT
# 1287483         NaN                          2011-08-12 06:21:00-04:00  NaT
# 224438          NaN                          2014-06-20 10:35:00-04:00  NaT
# 584734          NaN                          2011-08-01 08:55:00-04:00  NaT
# 392771          NaN                          2011-07-08 15:10:00-04:00  NaT
# 764522          NaN                          2011-08-05 07:34:00-04:00  NaT
# 282633          NaN                          2011-08-05 03:07:00-04:00  NaT
# 71026           NaN                          2011-08-03 07:58:00-04:00  NaT
# 335765     340328.0  PowerShares DB Commodity Index Breaks Below He...  NaT
# 183655          NaN                          2011-11-01 12:52:00-04:00  NaT
# 911017     922951.0                      Auriga Upgrades NetApp to Buy  NaT
# 1110578         NaN                          2011-12-08 16:08:00-05:00  NaT
# 617919     628835.0  Harris Corporation Awarded $80 Million Healthc...  NaT
# 1330835   1344015.0  Wunderlich Reiterates Buy and PT of $35 on Was...  NaT
# 181205          NaN                          2011-07-19 07:54:00-04:00  NaT
# 1017993   1030268.0            Jefferies Reiterates Hold on PetroQuest  NaT
# 31225           NaN                          2014-06-20 10:28:00-04:00  NaT
# 1194165   1206909.0    Collins Stewart Reiterates Neutral on Synaptics  NaT
#
#         stock
# 1388370   NaN
# 351042    NaN
# 731960    NaN
# 1287483   NaN
# 224438    NaN
# 584734    NaN
# 392771    NaN
# 764522    NaN
# 282633    NaN
# 71026     NaN
# 335765    NaN
# 183655    NaN
# 911017    NaN
# 1110578   NaN
# 617919    NaN
# 1330835   NaN
# 181205    NaN
# 1017993   NaN
# 31225     NaN
# 1194165   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8502 entries, 0 to 8501
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    8502 non-null   datetime64[ns, UTC]
#  1   OPEN    8502 non-null   float64
#  2   HIGH    8502 non-null   float64
#  3   LOW     8502 non-null   float64
#  4   CLOSE   8502 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(4)
# memory usage: 332.2 KB

# %%
#df_hdl.drop('Unnamed: 0', axis=1, inplace=True)
df_hdl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400469 entries, 0 to 1400468
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1399180 non-null  float64
#  1   title       1400469 non-null  object
#  2   date        1397891 non-null  datetime64[ns, UTC]
#  3   stock       1397891 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(1), object(2)
# memory usage: 42.7+ MB

# %%
#Chop off dates here?? 
#df = df[df['DATE'] >= df_hdl['date'].min()]
#df = df[df['DATE'] <= df_hdl['date'].max()]

# %%
# df1 is just the VIX indexed by date
# df2 is just the closing price indexed by date
df1 = df.copy().set_index('DATE')
df2 = df1[['CLOSE']]
###############################################
## VIX changed format to allow options in 2003
#################################################
df2 = df2[df2.index > '2003-01-01']
df.head()
# Out:
#                        DATE   OPEN   HIGH    LOW  CLOSE
# 0 1990-01-02 00:00:00+00:00  17.24  17.24  17.24  17.24
# 1 1990-01-03 00:00:00+00:00  18.19  18.19  18.19  18.19
# 2 1990-01-04 00:00:00+00:00  19.22  19.22  19.22  19.22
# 3 1990-01-05 00:00:00+00:00  20.11  20.11  20.11  20.11
# 4 1990-01-08 00:00:00+00:00  20.26  20.26  20.26  20.26

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5226 entries, 2003-01-02 00:00:00+00:00 to 2023-09-20 00:00:00+00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CLOSE   5226 non-null   float64
# dtypes: float64(1)
# memory usage: 81.7 KB

# %% [markdown]
# ## Text of Headlines
# ### Data
# Now look at the headlines

# %%
df_hdl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400469 entries, 0 to 1400468
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1399180 non-null  float64
#  1   title       1400469 non-null  object
#  2   date        1397891 non-null  datetime64[ns, UTC]
#  3   stock       1397891 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(1), object(2)
# memory usage: 42.7+ MB

# %%
df_hdl['date'] = df_hdl['date'].dt.date

# %%
df_hdl.head()
# Out:
#    Unnamed: 0                                              title        date  \
# 0         0.0            Stocks That Hit 52-Week Highs On Friday  2020-06-05
# 1         1.0         Stocks That Hit 52-Week Highs On Wednesday  2020-06-03
# 2         2.0                      71 Biggest Movers From Friday  2020-05-26
# 3         3.0       46 Stocks Moving In Friday's Mid-Day Session  2020-05-22
# 4         4.0  B of A Securities Maintains Neutral on Agilent...  2020-05-22
#
#   stock
# 0     A
# 1     A
# 2     A
# 3     A
# 4     A

# %%
## the null values are all in the same places so drop them
len(df_hdl[df_hdl['date'].isnull() & df_hdl['stock'].isnull()])
# Out:
# 2578

# %%
df_hdl.dropna(how='any',axis=0, inplace=True)
df_hdl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1397891 entries, 0 to 1400468
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1397891 non-null  float64
#  1   title       1397891 non-null  object
#  2   date        1397891 non-null  object
#  3   stock       1397891 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 53.3+ MB

# %%
## Add VADER sentiment analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyser = SentimentIntensityAnalyzer()

def vader_compound(sentence):
    score = analyser.polarity_scores(sentence)
    return score['compound']

# %%
#Apply Compound score
df_hdl['compound'] = df_hdl['title'].apply(vader_compound)

# %%
##  Positive Negative Neutral Classification of each
def sentiment(compound):
  if compound >= 0.05:
    return 'Positive'
  elif compound <= -0.05:
    return 'Negative'
  else:
    return 'Neutral'

# %%
df_hdl['sentiment'] = df_hdl['compound'].apply(lambda x: sentiment(x))

# %%
len(df_hdl['date'].unique())
# Out:
# 3959

# %%
counts = df_hdl['sentiment'].value_counts()

# plot the bar chart
counts.plot(kind='bar', xlabel='Category', ylabel='Count', rot=0)
plt.show()

# %%
#Aggregate retweet count and fav_count by date, concat tweet and tweetType 
number = df_hdl.groupby('date').sum().reset_index()
headlines = df_hdl.groupby('date')['title'].apply(lambda x: ', '.join(x)).reset_index()
sentiments = df_hdl.groupby('date')['sentiment'].apply(lambda x: ', '.join(x)).reset_index()
stocks = df_hdl.groupby('date')['stock'].apply(lambda x: ', '.join(x)).reset_index()

# %%
# this dataframe aggregates by date and sums/concatenates everything 
## the relevant sum is compound which is the sum of the vader scores for the day's headlines
number.sample(5)
# Out:
#             date   Unnamed: 0  \
# 2915  2017-07-24  348651826.0
# 2527  2016-06-23  334958198.0
# 2894  2017-07-03  131461112.0
# 113   2009-10-30   56111204.0
# 2023  2015-02-04  554895766.0
#
#                                                   title  \
# 2915  Agilent Acquires Powerful Next Gen Sequencing ...
# 2527  FBR Capital Initiates Coverage on American Cam...
# 2894  There's Nothing Soft About This Software ETF10...
# 113   Top NYSE Financial Stocks To Consider (JPM, BA...
# 2023  Asbury Automotive Announces $300M Buyback Plan...
#
#                                                   stock  compound  \
# 2915  AACCACCACMACMACRXADCADCAEMAEOAEZSAIRTALVAMAGAM...   35.8942
# 2527  ACCACNACNACNACNACNAETAETAETAETAGNAGNAIGALEXALE...   51.6578
# 2894  ADBEAGAGAGENAKSAKSAKSALGNATVIAVAVAVAVAVAVAVAVA...    4.0805
# 113   ABAETAGNAHCAROAXTIAXTIAXTIAZNBJKBLKCBGCBSTCHKC...    8.8626
# 2023  ABGABGABGACASACHNACREACSFACTACXMADEPADEPADMADM...   60.6021
#
#                                               sentiment
# 2915  PositiveNeutralNeutralNeutralPositiveNeutralPo...
# 2527  NeutralNeutralNeutralNeutralNeutralNeutralPosi...
# 2894  NeutralNegativeNeutralPositivePositiveNeutralN...
# 113   PositivePositiveNeutralPositiveNegativePositiv...
# 2023  NeutralNeutralNeutralNegativeNegativePositiveN...

# %%
## the text dataframe contains the titles for each date separated by commas 
## may need to clean all the commas out of the individual headlines first
headlines.sample(5)
# Out:
#             date                                              title
# 3779  2019-12-15  The Week Ahead In Biotech: Avadel, Epizyme In ...
# 2717  2017-01-06  BMO Capital Downgrades Archer-Daniels Midland ...
# 3351  2018-10-12  Stocks Which Set New 52-Week Low Yesterday, Oc...
# 3690  2019-09-17  Benzinga's Top Upgrades, Downgrades For Septem...
# 3179  2018-04-21  Insider Buys Of The Week: JPMorgan, Salesforce...

# %%
## the sentiments dataframe contains the sentiments for each date separated by commas
sentiments.sample(5)
# Out:
#             date                                          sentiment
# 980   2012-03-23  Neutral, Neutral, Neutral, Negative, Neutral, ...
# 1075  2012-06-27  Negative, Positive, Positive, Neutral, Positiv...
# 2423  2016-03-11  Neutral, Neutral, Neutral, Neutral, Negative, ...
# 1589  2013-11-25  Neutral, Positive, Positive, Positive, Neutral...
# 1433  2013-06-21  Neutral, Negative, Positive, Negative, Negativ...

# %%
#Merge the dataframes together 
df3 = pd.merge(sentiments, headlines, how='outer', on='date')
df3 = pd.merge(df3, stocks, how='outer', on='date')
df3 = pd.merge(df3, number, how = 'outer', on = 'date')
df3.head()
# Out:
#          date                   sentiment_x  \
# 0  2009-02-14                      Positive
# 1  2009-04-27              Neutral, Neutral
# 2  2009-04-29                       Neutral
# 3  2009-05-22                       Neutral
# 4  2009-05-27  Positive, Positive, Positive
#
#                                              title_x         stock_x  \
# 0                       How Treasuries and ETFs Work             NAV
# 1  Update on the Luxury Sector: 2nd Quarter 2009,...           FT, Y
# 2                             Going Against the Herd               A
# 3  Charles Sizemore Radio Interview Saturday Morning              AM
# 4  JVA perks to 39% gain, SMCG ready, MRM to cont...  EPS, GMCR, JVA
#
#    Unnamed: 0                                            title_y     stock_y  \
# 0    883755.0                       How Treasuries and ETFs Work         NAV
# 1   1919075.0  Update on the Luxury Sector: 2nd Quarter 2009U...         FTY
# 2      1834.0                             Going Against the Herd           A
# 3     68387.0  Charles Sizemore Radio Interview Saturday Morning          AM
# 4   1706521.0  JVA perks to 39% gain, SMCG ready, MRM to cont...  EPSGMCRJVA
#
#    compound               sentiment_y
# 0    0.2263                  Positive
# 1    0.0000            NeutralNeutral
# 2    0.0000                   Neutral
# 3    0.0000                   Neutral
# 4    2.1288  PositivePositivePositive

# %%
#Do a Count of headlines  of each type make it into 3 columns 
categories = ['Positive', 'Neutral', 'Negative']

for x in categories:
  for a in df3['sentiment_x']:
    df3[x] = [a.count(x) for a in df3['sentiment_x']]

# %%
df3.head()
# Out:
#          date                   sentiment_x  \
# 0  2009-02-14                      Positive
# 1  2009-04-27              Neutral, Neutral
# 2  2009-04-29                       Neutral
# 3  2009-05-22                       Neutral
# 4  2009-05-27  Positive, Positive, Positive
#
#                                              title_x         stock_x  \
# 0                       How Treasuries and ETFs Work             NAV
# 1  Update on the Luxury Sector: 2nd Quarter 2009,...           FT, Y
# 2                             Going Against the Herd               A
# 3  Charles Sizemore Radio Interview Saturday Morning              AM
# 4  JVA perks to 39% gain, SMCG ready, MRM to cont...  EPS, GMCR, JVA
#
#    Unnamed: 0                                            title_y     stock_y  \
# 0    883755.0                       How Treasuries and ETFs Work         NAV
# 1   1919075.0  Update on the Luxury Sector: 2nd Quarter 2009U...         FTY
# 2      1834.0                             Going Against the Herd           A
# 3     68387.0  Charles Sizemore Radio Interview Saturday Morning          AM
# 4   1706521.0  JVA perks to 39% gain, SMCG ready, MRM to cont...  EPSGMCRJVA
#
#    compound               sentiment_y  Positive  Neutral  Negative
# 0    0.2263                  Positive         1        0         0
# 1    0.0000            NeutralNeutral         0        2         0
# 2    0.0000                   Neutral         0        1         0
# 3    0.0000                   Neutral         0        1         0
# 4    2.1288  PositivePositivePositive         3        0         0

# %%
df3.drop(columns=['title_y','Unnamed: 0','stock_y', 'sentiment_y'], inplace=True)
df3.rename(columns = {'sentiment_x':'sentiments', 'title_x':'headlines', 'compound':'summed_vader', 'stock_x':'stocks'}, inplace = True)
df3.head()
# Out:
#          date                    sentiments  \
# 0  2009-02-14                      Positive
# 1  2009-04-27              Neutral, Neutral
# 2  2009-04-29                       Neutral
# 3  2009-05-22                       Neutral
# 4  2009-05-27  Positive, Positive, Positive
#
#                                            headlines          stocks  \
# 0                       How Treasuries and ETFs Work             NAV
# 1  Update on the Luxury Sector: 2nd Quarter 2009,...           FT, Y
# 2                             Going Against the Herd               A
# 3  Charles Sizemore Radio Interview Saturday Morning              AM
# 4  JVA perks to 39% gain, SMCG ready, MRM to cont...  EPS, GMCR, JVA
#
#    summed_vader  Positive  Neutral  Negative
# 0        0.2263         1        0         0
# 1        0.0000         0        2         0
# 2        0.0000         0        1         0
# 3        0.0000         0        1         0
# 4        2.1288         3        0         0

# %%
df3['Total'] = df3.Positive + df3.Neutral + df3.Negative
df3['ave_vader'] = df3.summed_vader / df3.Total
df3['daily_sentiment'] = df3['ave_vader'].apply(lambda x: sentiment(x))
df3.sample(10)
# Out:
#             date                                         sentiments  \
# 3897  2020-04-11  Neutral, Positive, Negative, Negative, Positiv...
# 3483  2019-02-21  Negative, Neutral, Negative, Neutral, Positive...
# 1325  2013-03-05  Positive, Positive, Positive, Neutral, Neutral...
# 1958  2014-12-01  Neutral, Neutral, Neutral, Neutral, Positive, ...
# 1865  2014-08-30  Negative, Neutral, Negative, Neutral, Neutral,...
# 3081  2018-01-11  Neutral, Positive, Positive, Neutral, Positive...
# 3092  2018-01-22  Positive, Negative, Neutral, Neutral, Neutral,...
# 2783  2017-03-14  Neutral, Positive, Negative, Neutral, Neutral,...
# 1080  2012-07-02  Negative, Positive, Neutral, Positive, Neutral...
# 1572  2013-11-08  Positive, Negative, Neutral, Neutral, Neutral,...
#
#                                               headlines  \
# 3897  Benzinga's Bulls And Bears Of The Week: Apple,...
# 3483  Barclays Maintains Overweight on Agilent Techn...
# 1325  UPDATE: Credit Suisse Initiates Agilent Techno...
# 1958  UPDATE:  Actavis Launches Generic Version of I...
# 1865  'Labor Day Sale On Abercrombie' After Lower Q2...
# 3081  Raymond James Upgrades Alcentra Capital to Mar...
# 3092  Abaxis Announces USDA Approval of New VetScan ...
# 2783  Aoxin Tianli Group Reports Q4 EPS $0.05 vs. $0...
# 1080  Benzinga's Top Pre-Market Losers, American Cam...
# 1572  Arbor Realty Trust Reports Q3 EPS of $0.08 vs ...
#
#                                                  stocks  summed_vader  \
# 3897  AAPL, EWI, EWI, EWU, EWU, HOG, IBB, LAZ, LLY, ...       -1.4972
# 3483  A, AAOI, AAOI, AAOI, ACET, ACET, ACRE, ADC, AD...       57.2519
# 1325  A, A, ABC, ABC, ACAT, ACM, ACUR, ACUR, ACUR, A...       34.6983
# 1958  ACT, ACT, AEO, AET, AET, AEZS, AFAM, AFSI, AGI...       51.4577
# 1865  ANF, BIG, BMY, BSX, CAFE, CCJ, CHA, DHI, EEM, ...       -0.3670
# 3081  ABDC, ADSK, AEO, AEO, AET, AFSI, AGN, AGN, AIR...       56.2268
# 3092  ABAX, ACH, ACOR, ADBE, ADBE, ADBE, ADBE, ADBE,...       62.1976
# 2783  ABAC, ABBV, ABCD, ACLS, ADI, ADI, AET, AGN, AG...       30.2477
# 1080  ACAT, ACC, ACM, ACM, ACTG, ACTG, ADI, ADI, ADM...       16.0155
# 1572  ABR, ABX, ACM, ACM, ACT, ADBE, ADBE, ADXS, AEG...       19.3343
#
#       Positive  Neutral  Negative  Total  ave_vader daily_sentiment
# 3897         2        7         6     15  -0.099813        Negative
# 3483       216      407        89    712   0.080410        Positive
# 1325       176      351        93    620   0.055965        Positive
# 1958       233      270       109    612   0.084081        Positive
# 1865         1       19         3     23  -0.015957         Neutral
# 3081       188      205        40    433   0.129854        Positive
# 3092       193      334        42    569   0.109310        Positive
# 2783       190      229        79    498   0.060738        Positive
# 1080       139      216       116    471   0.034003         Neutral
# 1572       113      182        68    363   0.053263        Positive

# %%
df3.tail()
# Out:
#             date                                         sentiments  \
# 3954  2020-06-07  Positive, Neutral, Neutral, Neutral, Neutral, ...
# 3955  2020-06-08  Positive, Neutral, Positive, Positive, Neutral...
# 3956  2020-06-09  Neutral, Neutral, Positive, Positive, Neutral,...
# 3957  2020-06-10  Negative, Neutral, Negative, Positive, Neutral...
# 3958  2020-06-11  Neutral, Neutral, Neutral, Neutral, Negative, ...
#
#                                               headlines  \
# 3954  Apple's Top Supplier Foxconn Launched New Recr...
# 3955  Shares of several retail and apparel companies...
# 3956  Why Apple's Stock Is Trading Higher Today, App...
# 3957  Shares of retail & apparel companies are tradi...
# 3958  Johnson & Johnson To Start Coronavirus Vaccine...
#
#                                                  stocks  summed_vader  \
# 3954  AAPL, ADXS, AGIO, ALNY, AMZN, AZN, BAM, BLUE, ...        0.4137
# 3955  AAN, AAN, AAPL, AAPL, AAPL, AAWW, ABBV, ABEV, ...      206.5643
# 3956  AAPL, AAPL, AAPL, AAPL, AAPL, AAPL, AAPL, AAPL...      235.3178
# 3957  AAN, AAN, AAP, AAPL, AAPL, AAPL, AAPL, AAPL, A...       35.1903
# 3958  AZN, CANF, CHK, CHS, CNHI, DHI, DPW, EOG, EPR,...       67.2846
#
#       Positive  Neutral  Negative  Total  ave_vader daily_sentiment
# 3954         6       23         3     32   0.012928         Neutral
# 3955       425      415        68    908   0.227494        Positive
# 3956       441      354        88    883   0.266498        Positive
# 3957       269      339       212    820   0.042915         Neutral
# 3958       323      118       105    546   0.123232        Positive

# %%
## Merge with the VIX data
# prep the date first
df = df.rename(columns={'DATE':'date'})
df['date'] = df['date'].dt.date
df.head()
# Out:
#          date   OPEN   HIGH    LOW  CLOSE
# 0  1990-01-02  17.24  17.24  17.24  17.24
# 1  1990-01-03  18.19  18.19  18.19  18.19
# 2  1990-01-04  19.22  19.22  19.22  19.22
# 3  1990-01-05  20.11  20.11  20.11  20.11
# 4  1990-01-08  20.26  20.26  20.26  20.26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8502 entries, 0 to 8501
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    8502 non-null   object
#  1   OPEN    8502 non-null   float64
#  2   HIGH    8502 non-null   float64
#  3   LOW     8502 non-null   float64
#  4   CLOSE   8502 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 332.2+ KB

# %%
df4 = pd.merge(df3, df, how='left', on='date')
df4.head()
# Out:
#          date                    sentiments  \
# 0  2009-02-14                      Positive
# 1  2009-04-27              Neutral, Neutral
# 2  2009-04-29                       Neutral
# 3  2009-05-22                       Neutral
# 4  2009-05-27  Positive, Positive, Positive
#
#                                            headlines          stocks  \
# 0                       How Treasuries and ETFs Work             NAV
# 1  Update on the Luxury Sector: 2nd Quarter 2009,...           FT, Y
# 2                             Going Against the Herd               A
# 3  Charles Sizemore Radio Interview Saturday Morning              AM
# 4  JVA perks to 39% gain, SMCG ready, MRM to cont...  EPS, GMCR, JVA
#
#    summed_vader  Positive  Neutral  Negative  Total  ave_vader  \
# 0        0.2263         1        0         0      1     0.2263
# 1        0.0000         0        2         0      2     0.0000
# 2        0.0000         0        1         0      1     0.0000
# 3        0.0000         0        1         0      1     0.0000
# 4        2.1288         3        0         0      3     0.7096
#
#   daily_sentiment   OPEN   HIGH    LOW  CLOSE
# 0        Positive    NaN    NaN    NaN    NaN
# 1         Neutral  39.46  39.52  37.97  38.32
# 2         Neutral  37.95  37.95  35.37  36.08
# 3         Neutral  31.36  32.71  30.57  32.63
# 4        Positive  30.80  32.53  29.62  32.36

# %%
len(df3)
# Out:
# 3959

# %%
df4.info()
# Comparison says there were 1198 non-trading days
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3959 entries, 0 to 3958
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             3959 non-null   object
#  1   sentiments       3959 non-null   object
#  2   headlines        3959 non-null   object
#  3   stocks           3959 non-null   object
#  4   summed_vader     3959 non-null   float64
#  5   Positive         3959 non-null   int64
#  6   Neutral          3959 non-null   int64
#  7   Negative         3959 non-null   int64
#  8   Total            3959 non-null   int64
#  9   ave_vader        3959 non-null   float64
#  10  daily_sentiment  3959 non-null   object
#  11  OPEN             2761 non-null   float64
#  12  HIGH             2761 non-null   float64
#  13  LOW              2761 non-null   float64
#  14  CLOSE            2761 non-null   float64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 464.1+ KB

# %%
#df4[df4.CLOSE.isnull()].groupby('dayOfWeek').date.count()

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3959 entries, 0 to 3958
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             3959 non-null   object
#  1   sentiments       3959 non-null   object
#  2   headlines        3959 non-null   object
#  3   stocks           3959 non-null   object
#  4   summed_vader     3959 non-null   float64
#  5   Positive         3959 non-null   int64
#  6   Neutral          3959 non-null   int64
#  7   Negative         3959 non-null   int64
#  8   Total            3959 non-null   int64
#  9   ave_vader        3959 non-null   float64
#  10  daily_sentiment  3959 non-null   object
#  11  OPEN             2761 non-null   float64
#  12  HIGH             2761 non-null   float64
#  13  LOW              2761 non-null   float64
#  14  CLOSE            2761 non-null   float64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 464.1+ KB

# %%
## Define a function which merges the row with the previous row
def row_combine_prev(row, sumcol, joincol):
    row.shift(1)[sumcol] = [row.col + row.shift(1).col for col in sumcol]
    row.shift(1)[joincol] = [row.col + ',' + row.shift(1).col for col in joincol]

# %%
df4.head()
# Out:
#          date                    sentiments  \
# 0  2009-02-14                      Positive
# 1  2009-04-27              Neutral, Neutral
# 2  2009-04-29                       Neutral
# 3  2009-05-22                       Neutral
# 4  2009-05-27  Positive, Positive, Positive
#
#                                            headlines          stocks  \
# 0                       How Treasuries and ETFs Work             NAV
# 1  Update on the Luxury Sector: 2nd Quarter 2009,...           FT, Y
# 2                             Going Against the Herd               A
# 3  Charles Sizemore Radio Interview Saturday Morning              AM
# 4  JVA perks to 39% gain, SMCG ready, MRM to cont...  EPS, GMCR, JVA
#
#    summed_vader  Positive  Neutral  Negative  Total  ave_vader  \
# 0        0.2263         1        0         0      1     0.2263
# 1        0.0000         0        2         0      2     0.0000
# 2        0.0000         0        1         0      1     0.0000
# 3        0.0000         0        1         0      1     0.0000
# 4        2.1288         3        0         0      3     0.7096
#
#   daily_sentiment   OPEN   HIGH    LOW  CLOSE
# 0        Positive    NaN    NaN    NaN    NaN
# 1         Neutral  39.46  39.52  37.97  38.32
# 2         Neutral  37.95  37.95  35.37  36.08
# 3         Neutral  31.36  32.71  30.57  32.63
# 4        Positive  30.80  32.53  29.62  32.36

# %%
sumcol = ['summed_vader','Positive','Negative', 'Neutral', 'Total']
joincol = ['sentiments','headlines','stocks']
df4.loc[df4['CLOSE'].isnull(),'date'] = None
df4['date'] = df4['date'].ffill()
df5 = df4.groupby('date').agg({'CLOSE':'max','Positive': 'sum','Negative':'sum','Neutral':'sum','Total':'sum', 'summed_vader':'sum',
                                'sentiments' :(lambda x: ', '.join(x)), 'headlines' :(lambda x: ', '.join(x)),
                               'stocks' :(lambda x: ', '.join(x)), 'date': ['min','max']}).reset_index()

# %%
len(df5)
# Out:
# 2761

# %%
df5.columns = pd.MultiIndex.from_tuples(df5.set_axis(df5.columns.values, axis=1)
                                       .rename(columns={('date', 'max'): ('max_date', ''), ('date','min'):('min_date','')}))

# %%
df5.columns = df5.columns.droplevel(1)
df5.columns
# Out:
# Index(['date', 'CLOSE', 'Positive', 'Negative', 'Neutral', 'Total',
#        'summed_vader', 'sentiments', 'headlines', 'stocks', 'min_date',
#        'max_date'],
#       dtype='object')

# %%
df5['max_date'] = pd.to_datetime(df5['max_date'])
df5['min_date'] = pd.to_datetime(df5['min_date'])
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2761 entries, 0 to 2760
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2761 non-null   object
#  1   CLOSE         2761 non-null   float64
#  2   Positive      2761 non-null   int64
#  3   Negative      2761 non-null   int64
#  4   Neutral       2761 non-null   int64
#  5   Total         2761 non-null   int64
#  6   summed_vader  2761 non-null   float64
#  7   sentiments    2761 non-null   object
#  8   headlines     2761 non-null   object
#  9   stocks        2761 non-null   object
#  10  min_date      2761 non-null   datetime64[ns]
#  11  max_date      2761 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(4), object(4)
# memory usage: 259.0+ KB

# %%
## Add day of week 
#  this might need to happen before the last step and tokenization may speed up the Vader
df5['dayOfWeek'] = df5['date'].apply(lambda x: x.strftime('%A'))

# %%
# Look for when the number of articles is small 
len(df5[(df5.min_date.dt.year > 2009) & (df5.Total < 20)])
# Out:
# 0

# %%
### Since 2009 has light articles lets look more closely
len(df5[(df5.min_date.dt.year == 2009) & (df5.Total < 20)])
# Out:
# 35

# %%
## Seems like a good start date might be Nov 1, 2009 or even easier drop 2009
print('The last date with less than 67 headlines is ', df5[(df5.Total  < 67)].date.max())
print('The last date with less than 100 headlines is ' ,df5[(df5.Total  < 100)].date.max())
# Out:
# The last date with less than 67 headlines is  2009-10-22
# The last date with less than 100 headlines is  2009-12-29

# %%
df5 = df5[(df5.min_date.dt.year > 2009)]

df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2628 entries, 133 to 2760
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2628 non-null   object
#  1   CLOSE         2628 non-null   float64
#  2   Positive      2628 non-null   int64
#  3   Negative      2628 non-null   int64
#  4   Neutral       2628 non-null   int64
#  5   Total         2628 non-null   int64
#  6   summed_vader  2628 non-null   float64
#  7   sentiments    2628 non-null   object
#  8   headlines     2628 non-null   object
#  9   stocks        2628 non-null   object
#  10  min_date      2628 non-null   datetime64[ns]
#  11  max_date      2628 non-null   datetime64[ns]
#  12  dayOfWeek     2628 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(4), object(5)
# memory usage: 287.4+ KB

# %%
## Check that no groupings span more than 3 days
df5['diff'] = df5.max_date - df5.min_date
df5[df5['diff'] > timedelta(days=3)]
# Out:
# Empty DataFrame
# Columns: [date, CLOSE, Positive, Negative, Neutral, Total, summed_vader, sentiments, headlines, stocks, min_date, max_date, dayOfWeek, diff]
# Index: []

# %%
### Days of the week are pretty even mondays are the most common holiday so that makes sense
df5.groupby('dayOfWeek').date.count()
# Out:
# dayOfWeek
# Friday       528
# Monday       492
# Thursday     531
# Tuesday      539
# Wednesday    538
# Name: date, dtype: int64

# %%
## Looks good!
df5.head(40)
# Out:
#            date  CLOSE  Positive  Negative  Neutral  Total  summed_vader  \
# 133  2010-01-04  20.04        52        17       96    165       13.7954
# 134  2010-01-05  19.35        84        15      103    202       34.1086
# 135  2010-01-06  19.16        74         8       86    168       23.6630
# 136  2010-01-07  19.06        90        29      106    225       24.1130
# 137  2010-01-08  18.13        80        26      111    217       16.3447
# 138  2010-01-11  17.55        88        18       92    198       28.7434
# 139  2010-01-12  18.25        82        32       99    213       18.5038
# 140  2010-01-13  17.85        62        19       80    161       15.6844
# 141  2010-01-14  17.63        86        33       76    195       12.9895
# 142  2010-01-15  17.91        94        38      128    260       23.2106
# 143  2010-01-19  17.58        66        12       86    164       16.6651
# 144  2010-01-20  18.68        81        22       80    183       16.0156
# 145  2010-01-21  22.27        58        17      103    178       12.4672
# 146  2010-01-22  27.31        77        20      119    216       18.0375
# 147  2010-01-25  25.41        96        26      107    229       24.6970
# 148  2010-01-26  24.55        63        33       92    188       10.4972
# 149  2010-01-27  23.14        87        15       99    201       30.3891
# 150  2010-01-28  23.73        65        25       90    180       12.3681
# 151  2010-01-29  24.62        75        25       77    177       24.5087
# 152  2010-02-01  22.59        59        17      115    191       11.6051
# 153  2010-02-02  21.48        65        20      173    258       16.0407
# 154  2010-02-03  21.60        60        37      109    206        8.9571
# 155  2010-02-04  26.08        72        27      123    222       14.7314
# 156  2010-02-05  26.11        67        33       98    198        9.6831
# 157  2010-02-08  26.51        57        22       93    172       13.2763
# 158  2010-02-09  26.00        71        21      135    227       15.3830
# 159  2010-02-10  25.40        86        21       93    200       20.2533
# 160  2010-02-11  23.96        83        29       93    205       15.4882
# 161  2010-02-12  22.73       115        31      156    302       23.7341
# 162  2010-02-16  22.25        78        27      106    211       23.2751
# 163  2010-02-17  21.72        68        29      113    210       18.1628
# 164  2010-02-18  20.63        82        23       93    198       23.3371
# 165  2010-02-19  20.02        83        21       93    197       21.4564
# 166  2010-02-22  19.94        85        35      115    235       14.5722
# 167  2010-02-23  21.37        95        35      107    237       21.8881
# 168  2010-02-24  20.27        86        24      135    245       19.6453
# 169  2010-02-25  20.10        57        35       83    175        9.1650
# 170  2010-02-26  19.50        65        25      141    231       13.5801
# 171  2010-03-01  19.26        44        32       91    167       12.0324
# 172  2010-03-02  19.06        52        20       88    160       13.6461
#
#                                             sentiments  \
# 133  Positive, Neutral, Neutral, Positive, Positive...
# 134  Neutral, Negative, Neutral, Positive, Neutral,...
# 135  Neutral, Neutral, Positive, Positive, Neutral,...
# 136  Positive, Negative, Neutral, Negative, Positiv...
# 137  Negative, Neutral, Positive, Negative, Positiv...
# 138  Neutral, Positive, Neutral, Positive, Neutral,...
# 139  Neutral, Positive, Positive, Positive, Positiv...
# 140  Positive, Negative, Positive, Neutral, Negativ...
# 141  Neutral, Neutral, Positive, Positive, Neutral,...
# 142  Neutral, Neutral, Negative, Neutral, Positive,...
# 143  Positive, Negative, Positive, Neutral, Positiv...
# 144  Neutral, Positive, Negative, Neutral, Positive...
# 145  Positive, Positive, Positive, Positive, Neutra...
# 146  Positive, Neutral, Neutral, Neutral, Negative,...
# 147  Neutral, Neutral, Neutral, Negative, Positive,...
# 148  Positive, Neutral, Neutral, Positive, Neutral,...
# 149  Neutral, Positive, Neutral, Positive, Neutral,...
# 150  Neutral, Positive, Negative, Negative, Positiv...
# 151  Positive, Neutral, Neutral, Neutral, Positive,...
# 152  Neutral, Neutral, Neutral, Neutral, Neutral, P...
# 153  Positive, Neutral, Positive, Positive, Neutral...
# 154  Neutral, Neutral, Positive, Positive, Neutral,...
# 155  Neutral, Neutral, Neutral, Positive, Positive,...
# 156  Neutral, Neutral, Neutral, Neutral, Negative, ...
# 157  Positive, Positive, Neutral, Negative, Neutral...
# 158  Neutral, Positive, Negative, Neutral, Neutral,...
# 159  Positive, Positive, Neutral, Positive, Neutral...
# 160  Neutral, Positive, Positive, Neutral, Neutral,...
# 161  Positive, Neutral, Neutral, Negative, Positive...
# 162  Neutral, Neutral, Positive, Neutral, Positive,...
# 163  Neutral, Positive, Positive, Negative, Negativ...
# 164  Positive, Positive, Positive, Neutral, Positiv...
# 165  Negative, Negative, Positive, Positive, Positi...
# 166  Neutral, Positive, Neutral, Neutral, Neutral, ...
# 167  Negative, Positive, Positive, Neutral, Negativ...
# 168  Neutral, Negative, Positive, Neutral, Negative...
# 169  Neutral, Negative, Neutral, Negative, Neutral,...
# 170  Positive, Neutral, Neutral, Neutral, Neutral, ...
# 171  Positive, Neutral, Positive, Positive, Neutral...
# 172  Neutral, Positive, Neutral, Positive, Neutral,...
#
#                                              headlines  \
# 133  Gold Gains Traction (GLD, GDX, IAG, NEM, ABX),...
# 134  Advance Auto Parts – A Turnaround Candidate (A...
# 135  Insurance Sector Overview - 2010 (AGII, SBX, A...
# 136  Benzinga’s Top Downgrades (WEN, CMP, ACL, PPDI...
# 137  Gold Finishes Lower After Pressure from the Do...
# 138  Aluminum on the Verge of Going Parabolic, Dorf...
# 139  AAP Lacks Near Term Catalysts, Benzinga’s Top ...
# 140  Benzinga’s Top Upgrades (BIDU, MRK, NTAP, UPS,...
# 141  Barrick Gold (ABX) Sues Its Rival Goldcorp Inc...
# 142  Mid Cap Biotechs May Outperform In 2010, Merri...
# 143  Top 5 Mid-Cap Stocks In The Services Sector Wi...
# 144  Fidelity Investments President Announces Retir...
# 145  Top 5 Mid-Cap Stocks In The Financial Sector W...
# 146  Benzinga’s Top Pre-Market Losers (ACHN, DEAR, ...
# 147  Auto Parts Retail Industry Update (ORLY, GPC, ...
# 148  AmerisourceBergen (ABC) Raises Profit Forecast...
# 149  Urban Outfitters (URBN) Undervalued, Airline S...
# 150  Benzinga’s Volume Movers (FFBC, NFLX, GNTX, AL...
# 151  Stocks That Created New 52-Week Highs (ACXM, B...
# 152  Zacks Bull and Bear of the Day Highlights: Hel...
# 153  Bank Bonds Become Attractive While Stocks Decl...
# 154  Benzinga’s Volume Movers (APKT, AUXL, NETL, MY...
# 155  Acorda (ACOR) Announces Ampyra Pricing, Archer...
# 156  Benzinga’s Volume Movers (SFLY, MPWR, OTEX, MD...
# 157  Aaron’s (AAN) Is Expected To Do Well: Barron’s...
# 158  Hedging With Gold Miners (AEM, GFI, NGD, DGL),...
# 159  Top 5 Mid-Cap Stocks In The Financial Sector W...
# 160  Vaccines Lift Sanofi's Revenues - Analyst Blog...
# 161  Agilent Technologies (A) Reports 23% Profit Ri...
# 162  Aaron’s, Inc. (AAN) Reports Fourth Quarter Num...
# 163  The Google Buzz Guide for the Enterprise (with...
# 164  Benzinga’s Top Downgrades (AAWW, ZNT, XNPT, DE...
# 165  AAP Reports Weak Q4, UBS Maintains Advance Aut...
# 166  Benzinga's Sector Leaders (AIG, TXT, PACR), St...
# 167  Acorda’s Q4 Loss In-Line With Expectations; Pl...
# 168  American Capital Ltd Price Target Of $5.50 (AC...
# 169  OMAB Reports In-line Results - Analyst Blog, 3...
# 170  Stocks That Created New 52-Week Highs (TDSC, A...
# 171  Companies That Could Benefit From Investing In...
# 172  2010 Fund Performance Period 2, Bookkeeping: C...
#
#                                                 stocks   min_date   max_date  \
# 133  ABX, ACTG, AEIS, AEO, AEO, AF, AF, AGO, AGQ, A... 2010-01-04 2010-01-04
# 134  AAP, ACE, ACN, ACN, ADBE, AEO, AFG, AHT, ALB, ... 2010-01-05 2010-01-05
# 135  ACE, AEIS, AGQ, AKS, ALL, ARE, ATI, ATVI, AXP,... 2010-01-06 2010-01-06
# 136  ABC, ACN, AEO, AEO, AER, AET, AGU, AIB, AIR, A... 2010-01-07 2010-01-07
# 137  ABX, AEO, AGU, AGU, AIB, AKS, ARO, ARO, ATHN, ... 2010-01-08 2010-01-08
# 138  ACH, ACN, ADTN, AEPI, AFSI, AGII, AINV, ALLT, ... 2010-01-11 2010-01-11
# 139  AAP, AAP, ACH, ACN, ADSK, AEO, AFL, AGU, AKS, ... 2010-01-12 2010-01-12
# 140  AAWW, ACIW, ACN, ADBE, ADBE, AET, AET, AFFX, A... 2010-01-13 2010-01-13
# 141  ABX, ACN, AEO, AGO, AIR, AMTD, AMX, AMX, AMX, ... 2010-01-14 2010-01-14
# 142  ACOR, ADBE, ADBE, ADSK, AEIS, AEO, AET, AGU, A... 2010-01-15 2010-01-15
# 143  ABC, ACAS, ACE, ACIW, ACN, ADTN, ADVS, AET, AE... 2010-01-19 2010-01-19
# 144  AB, ADM, ADSK, AET, AGQ, AIB, ALCO, ALD, ARCC,... 2010-01-20 2010-01-20
# 145  AB, AES, AKS, AMT, APC, ATHN, ATLS, AXP, AXP, ... 2010-01-21 2010-01-21
# 146  ACHN, ADS, ADS, AEIS, AEIS, AGQ, AKS, APH, ARM... 2010-01-22 2010-01-22
# 147  AAP, ABB, ACN, ACOR, ACXM, AKS, AKS, AKS, AKS,... 2010-01-25 2010-01-25
# 148  ABC, ABC, ADBE, AFAM, AGO, AGQ, AME, ARCC, ARO... 2010-01-26 2010-01-26
# 149  AEO, ALK, ALTR, ALTR, ALTR, ALTR, ALTR, AME, A... 2010-01-27 2010-01-27
# 150  ALGN, ALK, APC, ATK, ATK, AVY, AXP, AXP, AZN, ... 2010-01-28 2010-01-28
# 151  ACXM, ACXM, ACXM, ADBE, ADI, ADS, ALV, ALV, AL... 2010-01-29 2010-01-29
# 152  ADS, ADS, ADS, AET, AGU, ALV, APC, APC, APC, A... 2010-02-01 2010-02-01
# 153  AB, ACOR, ACOR, ADM, ADM, ADM, ADM, ADM, AEO, ... 2010-02-02 2010-02-02
# 154  ACOR, ACXM, ADM, ADP, ADS, ADS, ADS, AET, AFL,... 2010-02-03 2010-02-03
# 155  ACOR, ADM, AEM, AFFX, AFFX, AGN, AGN, AGO, AGQ... 2010-02-04 2010-02-04
# 156  ABCO, ADM, ADS, AEO, AET, AET, AET, AET, AGN, ... 2010-02-05 2010-02-05
# 157  AAN, ABX, ADS, AET, AET, AET, AGG, AGO, ALSK, ... 2010-02-08 2010-02-08
# 158  ABX, ACOR, ADSK, AEM, AGNC, AGNC, AGU, AMTD, A... 2010-02-09 2010-02-09
# 159  AB, ACC, ACE, ACOR, ADBE, ADBE, ADBE, ADM, ADM... 2010-02-10 2010-02-10
# 160  ADS, AET, ALL, AN, AN, API, ARRS, ASR, ATVI, A... 2010-02-11 2010-02-11
# 161  A, A, AAP, ADBE, AKS, ALL, ALL, ALSK, ATI, ATV... 2010-02-12 2010-02-12
# 162  AAN, ADSK, AEIS, AET, AGQ, AGU, AIV, AKS, AKS,... 2010-02-16 2010-02-16
# 163  A, ACOR, ADBE, AGN, AGN, AGN, AGN, AMTD, AMTD,... 2010-02-17 2010-02-17
# 164  AAWW, ABB, ABB, ABB, ABB, ABB, ACH, ACN, ADI, ... 2010-02-18 2010-02-18
# 165  AAP, AAP, ABX, ACN, ACXM, ADBE, AFK, AFSI, ALK... 2010-02-19 2010-02-19
# 166  ABB, ACXM, ADBE, AFSI, AFSI, AGU, AMTD, APC, A... 2010-02-22 2010-02-22
# 167  ACOR, ACUR, ACUR, ADBE, ADI, ADI, ADSK, AEO, A... 2010-02-23 2010-02-23
# 168  ACAS, ACAS, ADBE, ADBE, ADSK, ADSK, ADSK, ADSK... 2010-02-24 2010-02-24
# 169  ADS, AMSWA, AMT, AOL, ASH, ATHN, AVAV, BAM, BI... 2010-02-25 2010-02-25
# 170  AAWW, ACAS, ACN, ADS, AEG, AES, AGO, ALTR, ATH... 2010-02-26 2010-02-26
# 171  ABB, AF, ARIA, ATW, AUXL, AWI, AWK, AXP, AZO, ... 2010-03-01 2010-03-01
# 172  AGO, AGO, AGU, AIB, ALB, AMPH, AOS, ASA, ATML,... 2010-03-02 2010-03-02
#
#      dayOfWeek   diff
# 133     Monday 0 days
# 134    Tuesday 0 days
# 135  Wednesday 0 days
# 136   Thursday 0 days
# 137     Friday 0 days
# 138     Monday 0 days
# 139    Tuesday 0 days
# 140  Wednesday 0 days
# 141   Thursday 0 days
# 142     Friday 0 days
# 143    Tuesday 0 days
# 144  Wednesday 0 days
# 145   Thursday 0 days
# 146     Friday 0 days
# 147     Monday 0 days
# 148    Tuesday 0 days
# 149  Wednesday 0 days
# 150   Thursday 0 days
# 151     Friday 0 days
# 152     Monday 0 days
# 153    Tuesday 0 days
# 154  Wednesday 0 days
# 155   Thursday 0 days
# 156     Friday 0 days
# 157     Monday 0 days
# 158    Tuesday 0 days
# 159  Wednesday 0 days
# 160   Thursday 0 days
# 161     Friday 0 days
# 162    Tuesday 0 days
# 163  Wednesday 0 days
# 164   Thursday 0 days
# 165     Friday 0 days
# 166     Monday 0 days
# 167    Tuesday 0 days
# 168  Wednesday 0 days
# 169   Thursday 0 days
# 170     Friday 0 days
# 171     Monday 0 days
# 172    Tuesday 0 days

# %%
df5 = df5.drop(columns=['max_date','diff','date']).rename(columns={'min_date':'date'})
df5.head()
# Out:
#      CLOSE  Positive  Negative  Neutral  Total  summed_vader  \
# 133  20.04        52        17       96    165       13.7954
# 134  19.35        84        15      103    202       34.1086
# 135  19.16        74         8       86    168       23.6630
# 136  19.06        90        29      106    225       24.1130
# 137  18.13        80        26      111    217       16.3447
#
#                                             sentiments  \
# 133  Positive, Neutral, Neutral, Positive, Positive...
# 134  Neutral, Negative, Neutral, Positive, Neutral,...
# 135  Neutral, Neutral, Positive, Positive, Neutral,...
# 136  Positive, Negative, Neutral, Negative, Positiv...
# 137  Negative, Neutral, Positive, Negative, Positiv...
#
#                                              headlines  \
# 133  Gold Gains Traction (GLD, GDX, IAG, NEM, ABX),...
# 134  Advance Auto Parts – A Turnaround Candidate (A...
# 135  Insurance Sector Overview - 2010 (AGII, SBX, A...
# 136  Benzinga’s Top Downgrades (WEN, CMP, ACL, PPDI...
# 137  Gold Finishes Lower After Pressure from the Do...
#
#                                                 stocks       date  dayOfWeek
# 133  ABX, ACTG, AEIS, AEO, AEO, AF, AF, AGO, AGQ, A... 2010-01-04     Monday
# 134  AAP, ACE, ACN, ACN, ADBE, AEO, AFG, AHT, ALB, ... 2010-01-05    Tuesday
# 135  ACE, AEIS, AGQ, AKS, ALL, ARE, ATI, ATVI, AXP,... 2010-01-06  Wednesday
# 136  ABC, ACN, AEO, AEO, AER, AET, AGU, AIB, AIR, A... 2010-01-07   Thursday
# 137  ABX, AEO, AGU, AGU, AIB, AKS, ARO, ARO, ATHN, ... 2010-01-08     Friday

# %%
#df5['sentiments'] = [x for x in df5.sentiments.str.split(',')]
df5['sentiments'] = [x for x in df5.sentiments.str.split(',')]
# need to run all and check these are the same

# %%
df5.iloc[1].sentiments
# Out:
# ['Neutral',
#  ' Negative',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Negative',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Negative',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Negative',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Negative',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Negative',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Negative',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Negative',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Negative',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Negative',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Negative',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Negative',
#  ' Neutral',
#  ' Neutral',
#  ' Negative',
#  ' Neutral',
#  ' Positive',
#  ' Negative',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Positive',
#  ' Neutral',
#  ' Positive',
#  ' Neutral',
#  ' Neutral',
#  ' Negative',
#  ' Neutral']

# %%
len(df5.iloc[1].sentiments)
# Out:
# 202

# %%
df5.iloc[1].Total
# Out:
# 202

# %%
df5['stocks'] = [x for x in df5.stocks.str.split(',')]
### turn stocks into list 
## could also count and turn into dictionary

# %%
### bring back average vader score
df5['ave_vader'] = df5.summed_vader / df5.Total
### compute a daily sentiment using previous function
df5['daily_sentiment'] = df5['ave_vader'].apply(lambda x: sentiment(x))
df5.head()
# Out:
#      CLOSE  Positive  Negative  Neutral  Total  summed_vader  \
# 133  20.04        52        17       96    165       13.7954
# 134  19.35        84        15      103    202       34.1086
# 135  19.16        74         8       86    168       23.6630
# 136  19.06        90        29      106    225       24.1130
# 137  18.13        80        26      111    217       16.3447
#
#                                             sentiments  \
# 133  [Positive,  Neutral,  Neutral,  Positive,  Pos...
# 134  [Neutral,  Negative,  Neutral,  Positive,  Neu...
# 135  [Neutral,  Neutral,  Positive,  Positive,  Neu...
# 136  [Positive,  Negative,  Neutral,  Negative,  Po...
# 137  [Negative,  Neutral,  Positive,  Negative,  Po...
#
#                                              headlines  \
# 133  Gold Gains Traction (GLD, GDX, IAG, NEM, ABX),...
# 134  Advance Auto Parts – A Turnaround Candidate (A...
# 135  Insurance Sector Overview - 2010 (AGII, SBX, A...
# 136  Benzinga’s Top Downgrades (WEN, CMP, ACL, PPDI...
# 137  Gold Finishes Lower After Pressure from the Do...
#
#                                                 stocks       date  dayOfWeek  \
# 133  [ABX,  ACTG,  AEIS,  AEO,  AEO,  AF,  AF,  AGO... 2010-01-04     Monday
# 134  [AAP,  ACE,  ACN,  ACN,  ADBE,  AEO,  AFG,  AH... 2010-01-05    Tuesday
# 135  [ACE,  AEIS,  AGQ,  AKS,  ALL,  ARE,  ATI,  AT... 2010-01-06  Wednesday
# 136  [ABC,  ACN,  AEO,  AEO,  AER,  AET,  AGU,  AIB... 2010-01-07   Thursday
# 137  [ABX,  AEO,  AGU,  AGU,  AIB,  AKS,  ARO,  ARO... 2010-01-08     Friday
#
#      ave_vader daily_sentiment
# 133   0.083608        Positive
# 134   0.168854        Positive
# 135   0.140851        Positive
# 136   0.107169        Positive
# 137   0.075321        Positive

# %%
### Add VADER sentiment analyzer
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#
#analyser = SentimentIntensityAnalyzer()
#
#def vader_compound(sentence):
#    score = analyser.polarity_scores(sentence)
#    return score['compound']
#Apply function to all the headlines of the day
df5['compound'] = df5['headlines'].apply(vader_compound)

# %%
### not much in Neutral
len(df5[(df5.compound < .9) & (df5.compound > -.9)])
df5['overall_sentiment'] = df5['compound'].apply(lambda x: sentiment(x))

# %%
### the overall and daily sentiments match for all daily_sentiment 'Positive' and 'Negative'
len(df5[(df5.daily_sentiment != df5.overall_sentiment) & (df5.daily_sentiment != 'Neutral') ])
# Out:
# 0

# %%
## Basically eliminates all 'Neutral' sentiments
len(df5[df5.overall_sentiment == 'Neutral'])
# Out:
# 0

# %%
df5['Pos_minus_Neg'] = df5.Positive - df5.Negative
df5.head()
# Out:
#      CLOSE  Positive  Negative  Neutral  Total  summed_vader  \
# 133  20.04        52        17       96    165       13.7954
# 134  19.35        84        15      103    202       34.1086
# 135  19.16        74         8       86    168       23.6630
# 136  19.06        90        29      106    225       24.1130
# 137  18.13        80        26      111    217       16.3447
#
#                                             sentiments  \
# 133  [Positive,  Neutral,  Neutral,  Positive,  Pos...
# 134  [Neutral,  Negative,  Neutral,  Positive,  Neu...
# 135  [Neutral,  Neutral,  Positive,  Positive,  Neu...
# 136  [Positive,  Negative,  Neutral,  Negative,  Po...
# 137  [Negative,  Neutral,  Positive,  Negative,  Po...
#
#                                              headlines  \
# 133  Gold Gains Traction (GLD, GDX, IAG, NEM, ABX),...
# 134  Advance Auto Parts – A Turnaround Candidate (A...
# 135  Insurance Sector Overview - 2010 (AGII, SBX, A...
# 136  Benzinga’s Top Downgrades (WEN, CMP, ACL, PPDI...
# 137  Gold Finishes Lower After Pressure from the Do...
#
#                                                 stocks       date  dayOfWeek  \
# 133  [ABX,  ACTG,  AEIS,  AEO,  AEO,  AF,  AF,  AGO... 2010-01-04     Monday
# 134  [AAP,  ACE,  ACN,  ACN,  ADBE,  AEO,  AFG,  AH... 2010-01-05    Tuesday
# 135  [ACE,  AEIS,  AGQ,  AKS,  ALL,  ARE,  ATI,  AT... 2010-01-06  Wednesday
# 136  [ABC,  ACN,  AEO,  AEO,  AER,  AET,  AGU,  AIB... 2010-01-07   Thursday
# 137  [ABX,  AEO,  AGU,  AGU,  AIB,  AKS,  ARO,  ARO... 2010-01-08     Friday
#
#      ave_vader daily_sentiment  compound overall_sentiment  Pos_minus_Neg
# 133   0.083608        Positive    0.9982          Positive             35
# 134   0.168854        Positive    0.9997          Positive             69
# 135   0.140851        Positive    0.9993          Positive             66
# 136   0.107169        Positive    0.9986          Positive             61
# 137   0.075321        Positive    0.9984          Positive             54

# %%
df5.groupby('overall_sentiment').count()
# Out:
#                    CLOSE  Positive  Negative  Neutral  Total  summed_vader  \
# overall_sentiment
# Negative             100       100       100      100    100           100
# Positive            2528      2528      2528     2528   2528          2528
#
#                    sentiments  headlines  stocks  date  dayOfWeek  ave_vader  \
# overall_sentiment
# Negative                  100        100     100   100        100        100
# Positive                 2528       2528    2528  2528       2528       2528
#
#                    daily_sentiment  compound  Pos_minus_Neg
# overall_sentiment
# Negative                       100       100            100
# Positive                      2528      2528           2528

# %%
df5.groupby('daily_sentiment').count()
# Out:
#                  CLOSE  Positive  Negative  Neutral  Total  summed_vader  \
# daily_sentiment
# Negative            34        34        34       34     34            34
# Neutral            681       681       681      681    681           681
# Positive          1913      1913      1913     1913   1913          1913
#
#                  sentiments  headlines  stocks  date  dayOfWeek  ave_vader  \
# daily_sentiment
# Negative                 34         34      34    34         34         34
# Neutral                 681        681     681   681        681        681
# Positive               1913       1913    1913  1913       1913       1913
#
#                  compound  overall_sentiment  Pos_minus_Neg
# daily_sentiment
# Negative               34                 34             34
# Neutral               681                681            681
# Positive             1913               1913           1913

# %%
len(df5[((df5.Pos_minus_Neg < 0)  | (df5.overall_sentiment == 'Negative')) & (df5.daily_sentiment == 'Positive')])
# Out:
# 1

# %%
df6 = df5
df6.loc[df5.Pos_minus_Neg < 0, 'daily_sentiment'] = 'Negative'

# %%
df5.loc[df5.overall_sentiment == 'Negative', 'daily_sentiment'] = 'Negative'

# %%
df5.groupby('daily_sentiment').count()
# Out:
#                  CLOSE  Positive  Negative  Neutral  Total  summed_vader  \
# daily_sentiment
# Negative           141       141       141      141    141           141
# Neutral            575       575       575      575    575           575
# Positive          1912      1912      1912     1912   1912          1912
#
#                  sentiments  headlines  stocks  date  dayOfWeek  ave_vader  \
# daily_sentiment
# Negative                141        141     141   141        141        141
# Neutral                 575        575     575   575        575        575
# Positive               1912       1912    1912  1912       1912       1912
#
#                  compound  overall_sentiment  Pos_minus_Neg
# daily_sentiment
# Negative              141                141            141
# Neutral               575                575            575
# Positive             1912               1912           1912

# %% [markdown]
# ## still need to add in VIX values , adjust headlines back for weekends and holidays/nontrading

# %% [markdown]
# # EDA

# %%
#See if it is normally distributed 
qqplot(df2['CLOSE'], line='s')
plt.show()

# %%
df3 = df2.asfreq('D', method='ffill')
df3.head(10)

# %%
#df2.index = df2.index.to_period('D')

# %%
y = df2['CLOSE']

# %%
y.head(10)
# Out:
# DATE
# 2003-01-02 00:00:00+00:00    25.39
# 2003-01-03 00:00:00+00:00    24.68
# 2003-01-06 00:00:00+00:00    24.91
# 2003-01-07 00:00:00+00:00    25.13
# 2003-01-08 00:00:00+00:00    25.53
# 2003-01-09 00:00:00+00:00    24.25
# 2003-01-10 00:00:00+00:00    24.32
# 2003-01-13 00:00:00+00:00    24.90
# 2003-01-14 00:00:00+00:00    24.57
# 2003-01-15 00:00:00+00:00    25.51
# Name: CLOSE, dtype: float64

# %%
# import the appopriate function and set up
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(df3['CLOSE'], model='additive')
decomposition.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\snakes\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CLOSE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 3
#       1 # import the appopriate function and set up
#       2 import statsmodels.api as sm
# ----> 3 decomposition = sm.tsa.seasonal_decompose(df3['CLOSE'], model='additive')
#       4 decomposition.plot()
#
# File C:\ProgramData\Anaconda3\envs\snakes\lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File C:\ProgramData\Anaconda3\envs\snakes\lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'CLOSE'

# %%
plt.plot(y)
plt.show()

# %%
# import the appopriate function and set up
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(df3['CLOSE'], model='additive')
decomposition.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 3
#       1 # import the appopriate function and set up
#       2 import statsmodels.api as sm
# ----> 3 decomposition = sm.tsa.seasonal_decompose(y, model='additive')
#       4 decomposition.plot()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\seasonal.py:166, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     164         period = pfreq
#     165     else:
# --> 166         raise ValueError(
#     167             "You must specify a period or x must be a pandas object with "
#     168             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     169         )
#     170 if x.shape[0] < 2 * pfreq:
#     171     raise ValueError(
#     172         f"x must have 2 complete cycles requires {2 * pfreq} "
#     173         f"observations. x only has {x.shape[0]} observation(s)"
#     174     )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %% [markdown]
# ### Test for stationary

# %%
from statsmodels.tsa.stattools import kpss
kpss(y)

# %%
# Import mean_squared_error and ARIMA
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA

import warnings
warnings.filterwarnings('ignore')

# %%
# Make a function called evaluate_arima_model to find the MSE of a single ARIMA model 
def evaluate_arima(data, arima_order):
    # Needs to be an integer because it is later used as an index.
    # Use int()
    split= int(len(data) * 0.8) 
    # Make train and test variables, with 'train, test'
    train, test = data[0:split], data[split:len(data)]
    past=[x for x in train]
    # make predictions
    predictions = list()
    for i in range(len(test)):#timestep-wise comparison between test data and one-step prediction ARIMA model. 
        model = ARIMA(past, order=arima_order)
        model_fit = model.fit()
        future = model_fit.forecast()[0]
        predictions.append(future)
        past.append(test[i])
    # calculate out of sample error
    error = mean_squared_error(test, predictions)
    # Return the error
    return error

# %%
# Make a function to evaluate different ARIMA models with several different p, d, and q values.
# Make a function called evaluate_models to evaluate different ARIMA models with several different p, d, and q values.
def evaluate_models(dataset, p_values, d_values, q_values):
    best_score, best_cfg = float("inf"), None
    # Iterate through p_values
    for p in p_values:
        # Iterate through d_values
        for d in d_values:
            # Iterate through q_values
            for q in q_values:
                # p, d, q iterator variables in that order
                order = (p, d, q)
                try:
                    # Make a variable called mse for the Mean squared error
                    mse = evaluate_arima(dataset, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                    print('ARIMA%s MSE=%.3f' % (order,mse))
                except:
                    continue
    return print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# %%
# Now, we choose a couple of values to try for each parameter.
p_values = [x for x in range(0, 3)]
d_values = [x for x in range(0, 3)]
q_values = [x for x in range(0, 3)]

# %%
df2.head(10)

# %%
# plt.figure(figsize=(15,10))
# plt.plot(y)
# plt.plot(model_fit.predict(), color = 'red', alpha=.5)

# %%
# Finally, we can find the optimum ARIMA model for our data.
# Nb. this can take a while...!
#evaluate_models(series ,p_values, d_values, q_values)
#ARIMA_MSE(y, (1,1,0))

# %%
# %%time
# # split into train and test sets
# X = y.values
# size = int(len(X) * 0.8)
# train, test = X[0:size], X[size:len(X)]
# history = [x for x in train]
# predictions = list()
# # walk-forward validation
# for t in range(len(test)):
#     model = ARIMA(history, order=(1,0,0))
#     model_fit = model.fit()
#     output = model_fit.forecast()
#     yhat = output[0]
#     predictions.append(yhat)
#     obs = test[t]
#     history.append(obs)
# # evaluate forecasts
# rmse = np.sqrt(mean_squared_error(test, predictions))
# print('Test RMSE: %.3f' % rmse)
# # plot forecasts against actual outcomes
# plt.plot(test)
# plt.plot(predictions, color='red')
# plt.show()

# %%
# %%time
# # split into train and test sets
# X = df2.values
# size = int(len(X) * 0.8)
# train, test = X[0:size], X[size:len(X)]
# history = [x for x in train]
# predictions = list()
# # walk-forward validation
# for t in range(len(test)):
#     model = ARIMA(history, order=(1,0,0))
#     model_fit = model.fit()
#     output = model_fit.forecast()
#     yhat = output[0]
#     predictions.append(yhat)
#     obs = test[t]
#     history.append(obs)
# # evaluate forecasts
# rmse = np.sqrt(mean_squared_error(test, predictions))
# print('Test RMSE: %.3f' % rmse)
# # plot forecasts against actual outcomes
# plt.plot(test)
# plt.plot(predictions, color='red')
# plt.show()

# %%
# # Now, we choose a couple of values to try for each parameter.
# p_values = [x for x in range(0, 1)]
# d_values = [x for x in range(0, 3)]
# q_values = [x for x in range(0, 3)]

# %%
# %%time
# evaluate_models(df2.values,p_values, d_values, q_values )

# %%
# # Now, we choose a couple of values to try for each parameter.
# p_values = [x for x in range(1, 2)]
# d_values = [x for x in range(0, 3)]
# q_values = [x for x in range(0, 3)]

# %%
# %%time
# evaluate_models(df2.values,p_values, d_values, q_values )

# %%
# # Now, we choose a couple of values to try for each parameter.
# p_values = [x for x in range(2, 3)]
# d_values = [x for x in range(0, 3)]
# q_values = [x for x in range(0, 3)]

# %%
# %%time
# evaluate_models(df2.values,p_values, d_values, q_values )

# %%
# %%time
# evaluate_models(df2.values,p_values, d_values, q_values )

# %%
# # Now, we choose a couple of values to try for each parameter.
# p_values = [x for x in range(5, 6)]
# d_values = [x for x in range(0, 3)]
# q_values = [x for x in range(0, 3)]

# %%
# %%time
# evaluate_models(df2.values,p_values, d_values, q_values )
